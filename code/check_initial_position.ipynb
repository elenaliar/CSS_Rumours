# %% [markdown]
# ### Ways to show how the initial position affects the percolation

# %%
import numpy as np 
from simulation import run_multiple_simulations_for_phase_diagram, run_simulation, count_statuses
from visualisation import show_lecture_hall_over_time, plot_time_status
from ca_lecture_hall_model import Grid
from matplotlib import pyplot as plt

size = 20
spread_threshold = [0.1, 0.2, 0.3]
densities = [0.4, 0.5, 0.6]
num_simulations = 100
steps = 100

#put initial spreader in center
"""flag_center = 1
for spread in spread_threshold:
    for density in densities:
        print(f"Running simulation for density {density} and spread {spread} and flag_center {flag_center}")
        g = Grid(size, density, spread)
        g.initialize_board(flag_center)
        grids = run_simulation(g, steps)
        show_lecture_hall_over_time(grids)
        if g.check_percolation():
            print("Percolation occured")
        plt.show()

#put initial spreader outside of the center
flag_center = 0
for spread in spread_threshold:
    for density in densities:
        print(f"Running simulation for density {density} and spread {spread} and flag_center {flag_center}")
        g = Grid(size, density, spread)
        g.initialize_board(flag_center)
        grids = run_simulation(g, steps)
        show_lecture_hall_over_time(grids)
        if g.check_percolation():
            print("Percolation occured")
        plt.show()

"""
#center initial
flag_center = 1
for spread in spread_threshold:
    for density in densities:
        print(f"Running simulation for density {density} and spread {spread} and flag_center {flag_center}")
        plot_time_status(size, density, spread, steps, num_simulations, flag_center)

#outside initial
flag_center = 0
for spread in spread_threshold:
    for density in densities:
        print(f"Running simulation for density {density} and spread {spread} and flag_center {flag_center}")
        plot_time_status(size, density, spread, steps, num_simulations, flag_center)
# Out:
# Running simulation for density 0.4 and spread 0.1 and flag_center 1
# Running simulation for density 0.5 and spread 0.1 and flag_center 1
# Running simulation for density 0.6 and spread 0.1 and flag_center 1
# Running simulation for density 0.4 and spread 0.2 and flag_center 1
# Running simulation for density 0.5 and spread 0.2 and flag_center 1
# Running simulation for density 0.6 and spread 0.2 and flag_center 1
# Running simulation for density 0.4 and spread 0.3 and flag_center 1
# Running simulation for density 0.5 and spread 0.3 and flag_center 1
# Running simulation for density 0.6 and spread 0.3 and flag_center 1
# Running simulation for density 0.4 and spread 0.1 and flag_center 0
# Running simulation for density 0.5 and spread 0.1 and flag_center 0
# Running simulation for density 0.6 and spread 0.1 and flag_center 0
# Running simulation for density 0.4 and spread 0.2 and flag_center 0
# Running simulation for density 0.5 and spread 0.2 and flag_center 0
# Running simulation for density 0.6 and spread 0.2 and flag_center 0
# Running simulation for density 0.4 and spread 0.3 and flag_center 0
# Running simulation for density 0.5 and spread 0.3 and flag_center 0
# Running simulation for density 0.6 and spread 0.3 and flag_center 0
