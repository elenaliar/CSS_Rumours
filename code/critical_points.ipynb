# %% [markdown]
# Notebook to check how the model behaves for different pairs  of density/spread threshold

# %%
from visualisation import plot_percolation_vs_density_vs_spread_threshold, plot_3d_percolation_vs_density_and_threshold, plot_3d_gossip_spreader_counts, plot_time_status, plot_log_log_distribution, simulate_and_plot_gossip_model_all_combinations

densities = [0.6, 0.7, 0.8]
spread_thresholds = [0.1, 0.2, 0.3, 0.4]
grid_size = 20
num_simulation = 500
steps = 100

#flag_center=1 by default 
simulate_and_plot_gossip_model_all_combinations(grid_size, densities, spread_thresholds, num_simulation)

plot_3d_percolation_vs_density_and_threshold(grid_size, steps, num_simulation)
plot_3d_gossip_spreader_counts(grid_size, steps, num_simulation)

plot_percolation_vs_density_vs_spread_threshold(grid_size, steps, num_simulation)

#flag_center=0
flag_center=0   
simulate_and_plot_gossip_model_all_combinations(grid_size, densities, spread_thresholds, num_simulation, flag_center)

plot_3d_percolation_vs_density_and_threshold(grid_size, steps, num_simulation, flag_center)
plot_3d_gossip_spreader_counts(grid_size, steps, num_simulation, flag_center)
  
plot_percolation_vs_density_vs_spread_threshold(grid_size, steps, num_simulation, flag_center)
# Out:
# Running simulations for Density=0.6, Spread Threshold=0.1, Grid=20x20
# Percolation occured in 492 out of 500 simulations for density=0.6, spread_threshold=0.1
# Running simulations for Density=0.6, Spread Threshold=0.2, Grid=20x20
# Percolation occured in 435 out of 500 simulations for density=0.6, spread_threshold=0.2
# Running simulations for Density=0.6, Spread Threshold=0.3, Grid=20x20
# Percolation occured in 211 out of 500 simulations for density=0.6, spread_threshold=0.3
# Running simulations for Density=0.6, Spread Threshold=0.4, Grid=20x20
# Percolation occured in 33 out of 500 simulations for density=0.6, spread_threshold=0.4
# Running simulations for Density=0.7, Spread Threshold=0.1, Grid=20x20
# Percolation occured in 500 out of 500 simulations for density=0.7, spread_threshold=0.1
# Running simulations for Density=0.7, Spread Threshold=0.2, Grid=20x20
# Percolation occured in 496 out of 500 simulations for density=0.7, spread_threshold=0.2
# Running simulations for Density=0.7, Spread Threshold=0.3, Grid=20x20
# Percolation occured in 433 out of 500 simulations for density=0.7, spread_threshold=0.3
# Running simulations for Density=0.7, Spread Threshold=0.4, Grid=20x20
# Percolation occured in 202 out of 500 simulations for density=0.7, spread_threshold=0.4
# Running simulations for Density=0.8, Spread Threshold=0.1, Grid=20x20
# Percolation occured in 500 out of 500 simulations for density=0.8, spread_threshold=0.1
# Running simulations for Density=0.8, Spread Threshold=0.2, Grid=20x20
# Percolation occured in 499 out of 500 simulations for density=0.8, spread_threshold=0.2
# Running simulations for Density=0.8, Spread Threshold=0.3, Grid=20x20
# Percolation occured in 490 out of 500 simulations for density=0.8, spread_threshold=0.3
# Running simulations for Density=0.8, Spread Threshold=0.4, Grid=20x20
# Percolation occured in 403 out of 500 simulations for density=0.8, spread_threshold=0.4
# Simulating thresholds: 100%|██████████| 10/10 [1:56:46<00:00, 700.67s/it]
# Spread Thresholds: 100%|██████████| 10/10 [3:58:42<00:00, 1432.24s/it]
# Starting simulation for different spread thresholds and densities...
# Simulating thresholds: 100%|██████████| 10/10 [2:41:38<00:00, 969.83s/it]
# Simulations completed.
# Running simulations for Density=0.6, Spread Threshold=0.1, Grid=20x20
# Percolation occured in 472 out of 500 simulations for density=0.6, spread_threshold=0.1
# Running simulations for Density=0.6, Spread Threshold=0.2, Grid=20x20
# Percolation occured in 377 out of 500 simulations for density=0.6, spread_threshold=0.2
# Running simulations for Density=0.6, Spread Threshold=0.3, Grid=20x20
# Percolation occured in 163 out of 500 simulations for density=0.6, spread_threshold=0.3
# Running simulations for Density=0.6, Spread Threshold=0.4, Grid=20x20
# Percolation occured in 13 out of 500 simulations for density=0.6, spread_threshold=0.4
# Running simulations for Density=0.7, Spread Threshold=0.1, Grid=20x20
# Percolation occured in 497 out of 500 simulations for density=0.7, spread_threshold=0.1
# Running simulations for Density=0.7, Spread Threshold=0.2, Grid=20x20
# Percolation occured in 486 out of 500 simulations for density=0.7, spread_threshold=0.2
# Running simulations for Density=0.7, Spread Threshold=0.3, Grid=20x20
# Percolation occured in 396 out of 500 simulations for density=0.7, spread_threshold=0.3
# Running simulations for Density=0.7, Spread Threshold=0.4, Grid=20x20
# Percolation occured in 166 out of 500 simulations for density=0.7, spread_threshold=0.4
# Running simulations for Density=0.8, Spread Threshold=0.1, Grid=20x20
# Percolation occured in 498 out of 500 simulations for density=0.8, spread_threshold=0.1
# Running simulations for Density=0.8, Spread Threshold=0.2, Grid=20x20
# Percolation occured in 499 out of 500 simulations for density=0.8, spread_threshold=0.2
# Running simulations for Density=0.8, Spread Threshold=0.3, Grid=20x20
# Percolation occured in 479 out of 500 simulations for density=0.8, spread_threshold=0.3
# Running simulations for Density=0.8, Spread Threshold=0.4, Grid=20x20
# Percolation occured in 366 out of 500 simulations for density=0.8, spread_threshold=0.4
# Simulating thresholds: 100%|██████████| 10/10 [1:18:54<00:00, 473.41s/it]
# Spread Thresholds: 100%|██████████| 10/10 [37:54<00:00, 227.45s/it]
# Starting simulation for different spread thresholds and densities...
# Simulating thresholds: 100%|██████████| 10/10 [1:17:52<00:00, 467.25s/it]
# Simulations completed.
