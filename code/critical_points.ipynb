# %% [markdown]
# Notebook to check how the model behaves for different pairs  of density/spread threshold

# %%
from visualisation import plot_percolation_vs_density_vs_spread_threshold, plot_3d_percolation_vs_density_and_threshold, plot_3d_gossip_spreader_counts, plot_time_status, plot_log_log_distribution, simulate_and_plot_gossip_model_all_combinations
import matplotlib.pyplot as plt

densities = [0.6, 0.7, 0.8]
spread_thresholds = [0.1, 0.2, 0.3, 0.4]
grid_size = 20
num_simulation = 500
steps = 100
x_limits = (0, steps-20)
y_limits = (0, grid_size*grid_size)

# %%
#moore neighborhood
#flag_center =1
plot_3d_percolation_vs_density_and_threshold(grid_size, steps, num_simulation)
plot_3d_gossip_spreader_counts(grid_size, steps, num_simulation)

plot_percolation_vs_density_vs_spread_threshold(grid_size, steps, num_simulation)

#flag_center=0
flag_center=0   

plot_3d_percolation_vs_density_and_threshold(grid_size, steps, num_simulation, flag_center)
plot_3d_gossip_spreader_counts(grid_size, steps, num_simulation, flag_center)
  
plot_percolation_vs_density_vs_spread_threshold(grid_size, steps, num_simulation, flag_center)
# Out:
# Simulations for Moore neighborhood
# Simulating thresholds: 100%|██████████| 10/10 [1:09:12<00:00, 415.25s/it]
# Spread Thresholds: 100%|██████████| 10/10 [1:01:14<00:00, 367.41s/it]
# Starting simulation for different spread thresholds and densities...
# Simulating thresholds: 100%|██████████| 10/10 [3:08:40<00:00, 1132.03s/it]
# Simulations completed.
# Simulating thresholds: 100%|██████████| 10/10 [29:50<00:00, 179.05s/it]
# Spread Thresholds: 100%|██████████| 10/10 [1:50:45<00:00, 664.57s/it]
# Starting simulation for different spread thresholds and densities...
# Simulating thresholds: 100%|██████████| 10/10 [3:01:59<00:00, 1091.95s/it]
# Simulations completed.
# Simulations for Von Neumann neighborhood
# Starting simulation for different spread thresholds and densities...
# Simulating thresholds: 100%|██████████| 10/10 [55:05<00:00, 330.52s/it]
# Simulations completed.
# Starting simulation for different spread thresholds and densities...
# Simulating thresholds:  30%|███       | 3/10 [1:33:34<3:38:20, 1871.52s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 64
#      62 #flag_center=0
#      63 flag_center=0
# ---> 64 plot_percolation_vs_density_vs_spread_threshold(grid_size, steps, num_simulation, flag_center, flag_neighbors)
#
# File ~/Documents/master/block3/CSS_EscapePanic/code/visualisation.py:391, in plot_percolation_vs_density_vs_spread_threshold(grid_size, steps, num_simulations, flag_center, flag_neighbors)
#     384 print("Starting simulation for different spread thresholds and densities...")
#     386 for i, spread_threshold in tqdm(
#     387     enumerate(spread_thresholds),
#     388     desc="Simulating thresholds",
#     389     total=len(spread_thresholds),
#     390 ):
# --> 391     percolations = simulate_and_collect_percolations(
#     392         grid_size, densities, spread_threshold, steps, num_simulations, flag_center, flag_neighbors
#     393     )
#     394     plot_percolation_results(
#     395         densities, percolations, spread_threshold, color=colors[i]
#     396     )
#     398 print("Simulations completed.")
#
# File ~/Documents/master/block3/CSS_EscapePanic/code/simulation.py:333, in simulate_and_collect_percolations(grid_size, densities, spread_threshold, steps, num_simulations, flag_center, flag_neighbors)
#     330 percolations = []
#     331 for d in densities:
#     332     percolations.append(
# --> 333         simulate_density(grid_size, d, spread_threshold, steps, num_simulations, flag_center, flag_neighbors)
#     334     )
#     335 return percolations
#
# File ~/Documents/master/block3/CSS_EscapePanic/code/simulation.py:303, in simulate_density(grid_size, density, spread_threshold, steps, num_simulations, flag_center, flag_neighbors)
#     299 def simulate_density(grid_size, density, spread_threshold, steps, num_simulations, flag_center=1, flag_neighbors=1):
#     300     """
#     301     Simulates a single density and spread threshold and returns the fraction of simulations with percolation.
#     302     """
# --> 303     results = run_multiple_simulations_for_percolation(
#     304         grid_size, density, spread_threshold, steps, num_simulations, flag_center, flag_neighbors
#     305     )
#     306     return sum(results["simulation_outcomes"]) / num_simulations
#
# File ~/Documents/master/block3/CSS_EscapePanic/code/simulation.py:197, in run_multiple_simulations_for_percolation(grid_size, density, spread_threshold, steps, num_simulations, flag_center, flag_neighbors)
#     195     g = Grid(grid_size, density, spread_threshold)
#     196     g.initialize_board(flag_center)
# --> 197     run_simulation(g, steps, flag_neighbors)
#     198     results["simulation_outcomes"].append(g.check_percolation())
#     200 return results
#
# File ~/Documents/master/block3/CSS_EscapePanic/code/simulation.py:32, in run_simulation(grid, steps, flag_neighbors)
#      28 for step in range(steps):
#      29     # update the grid
#      30     grid.update_grid(flag_neighbors)
# ---> 32     current_grid = copy.deepcopy(grid.lecture_hall)
#      34     # check if any changes happened or not
#      35     if prev_grid == current_grid:
#
# File /opt/anaconda3/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File /opt/anaconda3/lib/python3.12/copy.py:196, in _deepcopy_list(x, memo, deepcopy)
#     194 append = y.append
#     195 for a in x:
# --> 196     append(deepcopy(a, memo))
#     197 return y
#
# File /opt/anaconda3/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File /opt/anaconda3/lib/python3.12/copy.py:196, in _deepcopy_list(x, memo, deepcopy)
#     194 append = y.append
#     195 for a in x:
# --> 196     append(deepcopy(a, memo))
#     197 return y
#
# File /opt/anaconda3/lib/python3.12/copy.py:145, in deepcopy(x, memo, _nil)
#     143     y = copier(memo)
#     144 else:
# --> 145     reductor = dispatch_table.get(cls)
#     146     if reductor:
#     147         rv = reductor(x)
#
# KeyboardInterrupt:

# %%
#Moore neighborhood
print("Simulations for Moore neighborhood")
#flag_center=1 by default 
fig, axs = plt.subplots(3, 4, figsize=(14, 12), constrained_layout=True)
fig.suptitle("Status counts over time", fontsize=24, y=1.1)
index = 0
flag_center=1
for i, density in enumerate(densities):
    for j, spread_threshold in enumerate(spread_thresholds):
        ax = axs[i, j]
        plot_time_status(ax, grid_size, density, spread_threshold, steps, num_simulation, flag_center, x_limits, y_limits)
        index += 1

handles, labels = axs[0, 0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', fontsize=14, ncol=4, bbox_to_anchor=(0.5, 1.05), frameon= False)
plt.show()
# Out:
# Simulations for Moore neighborhood

# %%
fig, axs = plt.subplots(3, 4, figsize=(14, 12), constrained_layout=True)
fig.suptitle("Status counts over time", fontsize=24, y=1.0)
index = 0
flag_center=0   
for i, density in enumerate(densities):
    for j, spread_threshold in enumerate(spread_thresholds):
        ax = axs[i, j]
        plot_time_status(ax, grid_size, density, spread_threshold, steps, num_simulation, flag_center, x_limits, y_limits)
        index+=1

handles, labels = axs[0, 0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', fontsize=14, ncol=4, bbox_to_anchor=(0.5, 1.05), frameon= False)
plt.show()
